# %% [markdown]
# ## 掛載雲端硬碟

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 更改檔案所在路徑

# %%
# Change to your own folder !!!
# %cd /content/drive/MyDrive/2025_EAI/Lab2-Prunning
# Out:
# /content/drive/MyDrive/2025_EAI/Lab2-Prunning

# %% [markdown]
# ## Import library

# %%
import os
import argparse

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

from resnet import ResNet50

# %% [markdown]
# ## 設定超參數

# %%
SEED = 1
TRAIN_BATCH_SIZE = 100
TEST_BATCH_SIZE = 1000
EPOCHS = 40
LEARNING_RATE = 1e-3
LOG_INTERVAL = 100
CUDA = True

RESUME = True
START_EPOCH = 0

PRUNE_PATH = '/content/drive/MyDrive/2025_EAI/Lab2-Prunning/model_prune.pth' # Change to your own folder !!!
PRUNE_FINETUNE_PATH = '/content/drive/MyDrive/2025_EAI/Lab2-Prunning/model_prune_finetune.pth' # Change to your own folder !!!

# %% [markdown]
# #### 檢查是否檢查是否可使用GPU

# %%
if(torch.cuda.is_available()):
    CUDA = True
    kwargs = {'num_workers': 1, 'pin_memory': True}
    torch.cuda.manual_seed(SEED)
else:
    CUDA = False
    kwargs = {}

# %% [markdown]
# ## 下載資料集

# %% [markdown]
# 這裡將訓練集做Augmentation(Pad, RandCrop, Random)，測試集不用做Augmentation

# %%
#### DATASET ####
train_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.Pad(4),
                       transforms.RandomCrop(32),
                       transforms.RandomHorizontalFlip(),
                       transforms.ToTensor(),
                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                   ])),
    batch_size=TRAIN_BATCH_SIZE, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                   ])),
    batch_size=TEST_BATCH_SIZE, shuffle=True, **kwargs)

# %% [markdown]
# ## 載入剪枝後的網路與權重

# %%
model = None
if(RESUME):
  checkpoint = torch.load(PRUNE_PATH)
  cfg = checkpoint['cfg']
  model = ResNet50(num_classes=10,cfg=cfg)
  model.load_state_dict(checkpoint['state_dict'])

  print('RESUME PRUNE MODEL')

if CUDA:
    model.cuda()
# Out:
# RESUME PRUNE MODEL

# %% [markdown]
# ## 設定 Optimizer & CrossEntropy Loss

# %%
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ## 定義訓練跟測試函數

# %%
#### 訓練函數 #####

# 注意: 需自行撰寫儲存每個epoch之train acc的code，以便後續繪製train acc結果圖!

train_acc = []

def train(epoch):
    model.train()

    correct = 0
    total = 0

    for batch_idx, (data, target) in enumerate(train_loader):
        if CUDA:
            data, target = data.cuda(), target.cuda()
        data, target = Variable(data), Variable(target)

        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).sum().item()
        total += target.size(0)

        if batch_idx % LOG_INTERVAL == 0:
            print('\nTrain Epoch: {} [{}/{} ({:.1f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data.item()))

    acc = 100. * correct / total
    train_acc.append(acc)

test_acc = []

#### 測試函數 ####
def test():
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
      for data, target in test_loader:
          if CUDA:
              data, target = data.cuda(), target.cuda()
          data, target = Variable(data), Variable(target)

          output = model(data)
          loss = criterion(output, target)
          test_loss += loss.item() * data.size(0)

          pred = output.data.max(1, keepdim=True)[1]
          correct += pred.eq(target.data.view_as(pred)).cpu().sum()

      test_loss /= len(test_loader.dataset)
      acc = 100. * correct / len(test_loader.dataset)
      test_acc.append(acc)

      print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
          test_loss, correct, len(test_loader.dataset),
          100. * correct / len(test_loader.dataset)))
      return correct / float(len(test_loader.dataset))


best_prec1 = 0.
for epoch in range(START_EPOCH, EPOCHS):
    # Learning Rate在0.5EPOCHS與0.75EPOCHS調整為原本之十分之一
    if epoch in [EPOCHS*0.5, EPOCHS*0.75]:
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.1
    train(epoch)
    prec1 = test()

    # 儲存模型權重
    if(prec1 > best_prec1):
        best_prec1 = prec1
        torch.save({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'best_prec1': best_prec1,
            'optimizer': optimizer.state_dict(),
            'cfg': cfg
        }, PRUNE_FINETUNE_PATH)

    best_prec1 = max(prec1, best_prec1)

print('\n TRAIN PRUNED MODEL DONE!')
# Out:
# Train Epoch: 0 [0/50000 (0.0%)]	Loss: 1.635030
#
# Train Epoch: 0 [10000/50000 (20.0%)]	Loss: 0.603852
#
# Train Epoch: 0 [20000/50000 (40.0%)]	Loss: 0.549600
#
# Train Epoch: 0 [30000/50000 (60.0%)]	Loss: 0.711195
#
# Train Epoch: 0 [40000/50000 (80.0%)]	Loss: 0.472123
#
# Test set: Average loss: 0.5424, Accuracy: 8197/10000 (82.0%)
#
#
# Train Epoch: 1 [0/50000 (0.0%)]	Loss: 0.441747
#
# Train Epoch: 1 [10000/50000 (20.0%)]	Loss: 0.426634
#
# Train Epoch: 1 [20000/50000 (40.0%)]	Loss: 0.555111
#
# Train Epoch: 1 [30000/50000 (60.0%)]	Loss: 0.483854
#
# Train Epoch: 1 [40000/50000 (80.0%)]	Loss: 0.394947
#
# Test set: Average loss: 0.6082, Accuracy: 8006/10000 (80.1%)
#
#
# Train Epoch: 2 [0/50000 (0.0%)]	Loss: 0.466147
#
# Train Epoch: 2 [10000/50000 (20.0%)]	Loss: 0.362658
#
# Train Epoch: 2 [20000/50000 (40.0%)]	Loss: 0.442658
#
# Train Epoch: 2 [30000/50000 (60.0%)]	Loss: 0.378845
#
# Train Epoch: 2 [40000/50000 (80.0%)]	Loss: 0.519058
#
# Test set: Average loss: 0.4751, Accuracy: 8416/10000 (84.2%)
#
#
# Train Epoch: 3 [0/50000 (0.0%)]	Loss: 0.432520
#
# Train Epoch: 3 [10000/50000 (20.0%)]	Loss: 0.279622
#
# Train Epoch: 3 [20000/50000 (40.0%)]	Loss: 0.380643
#
# Train Epoch: 3 [30000/50000 (60.0%)]	Loss: 0.423152
#
# Train Epoch: 3 [40000/50000 (80.0%)]	Loss: 0.297802
#
# Test set: Average loss: 0.5134, Accuracy: 8386/10000 (83.9%)
#
#
# Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.401569
#
# Train Epoch: 4 [10000/50000 (20.0%)]	Loss: 0.385183
#
# Train Epoch: 4 [20000/50000 (40.0%)]	Loss: 0.380369
#
# Train Epoch: 4 [30000/50000 (60.0%)]	Loss: 0.273743
#
# Train Epoch: 4 [40000/50000 (80.0%)]	Loss: 0.441911
#
# Test set: Average loss: 0.4628, Accuracy: 8530/10000 (85.3%)
#
#
# Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.437836
#
# Train Epoch: 5 [10000/50000 (20.0%)]	Loss: 0.236388
#
# Train Epoch: 5 [20000/50000 (40.0%)]	Loss: 0.425652
#
# Train Epoch: 5 [30000/50000 (60.0%)]	Loss: 0.594534
#
# Train Epoch: 5 [40000/50000 (80.0%)]	Loss: 0.465064
#
# Test set: Average loss: 0.4912, Accuracy: 8435/10000 (84.3%)
#
#
# Train Epoch: 6 [0/50000 (0.0%)]	Loss: 0.462715
#
# Train Epoch: 6 [10000/50000 (20.0%)]	Loss: 0.329349
#
# Train Epoch: 6 [20000/50000 (40.0%)]	Loss: 0.222373
#
# Train Epoch: 6 [30000/50000 (60.0%)]	Loss: 0.360795
#
# Train Epoch: 6 [40000/50000 (80.0%)]	Loss: 0.369992
#
# Test set: Average loss: 0.4735, Accuracy: 8506/10000 (85.1%)
#
#
# Train Epoch: 7 [0/50000 (0.0%)]	Loss: 0.399015
#
# Train Epoch: 7 [10000/50000 (20.0%)]	Loss: 0.400072
#
# Train Epoch: 7 [20000/50000 (40.0%)]	Loss: 0.289023
#
# Train Epoch: 7 [30000/50000 (60.0%)]	Loss: 0.401103
#
# Train Epoch: 7 [40000/50000 (80.0%)]	Loss: 0.335506
#
# Test set: Average loss: 0.4539, Accuracy: 8529/10000 (85.3%)
#
#
# Train Epoch: 8 [0/50000 (0.0%)]	Loss: 0.322571
#
# Train Epoch: 8 [10000/50000 (20.0%)]	Loss: 0.338315
#
# Train Epoch: 8 [20000/50000 (40.0%)]	Loss: 0.385334
#
# Train Epoch: 8 [30000/50000 (60.0%)]	Loss: 0.349625
#
# Train Epoch: 8 [40000/50000 (80.0%)]	Loss: 0.188613
#
# Test set: Average loss: 0.4862, Accuracy: 8489/10000 (84.9%)
#
#
# Train Epoch: 9 [0/50000 (0.0%)]	Loss: 0.289107
#
# Train Epoch: 9 [10000/50000 (20.0%)]	Loss: 0.288562
#
# Train Epoch: 9 [20000/50000 (40.0%)]	Loss: 0.393671
#
# Train Epoch: 9 [30000/50000 (60.0%)]	Loss: 0.416386
#
# Train Epoch: 9 [40000/50000 (80.0%)]	Loss: 0.325211
#
# Test set: Average loss: 0.4956, Accuracy: 8464/10000 (84.6%)
#
#
# Train Epoch: 10 [0/50000 (0.0%)]	Loss: 0.242828
#
# Train Epoch: 10 [10000/50000 (20.0%)]	Loss: 0.351085
#
# Train Epoch: 10 [20000/50000 (40.0%)]	Loss: 0.241153
#
# Train Epoch: 10 [30000/50000 (60.0%)]	Loss: 0.189891
#
# Train Epoch: 10 [40000/50000 (80.0%)]	Loss: 0.308890
#
# Test set: Average loss: 0.4758, Accuracy: 8484/10000 (84.8%)
#
#
# Train Epoch: 11 [0/50000 (0.0%)]	Loss: 0.295945
#
# Train Epoch: 11 [10000/50000 (20.0%)]	Loss: 0.236247
#
# Train Epoch: 11 [20000/50000 (40.0%)]	Loss: 0.505102
#
# Train Epoch: 11 [30000/50000 (60.0%)]	Loss: 0.316985
#
# Train Epoch: 11 [40000/50000 (80.0%)]	Loss: 0.370646
#
# Test set: Average loss: 0.4555, Accuracy: 8555/10000 (85.6%)
#
#
# Train Epoch: 12 [0/50000 (0.0%)]	Loss: 0.262486
#
# Train Epoch: 12 [10000/50000 (20.0%)]	Loss: 0.300212
#
# Train Epoch: 12 [20000/50000 (40.0%)]	Loss: 0.289310
#
# Train Epoch: 12 [30000/50000 (60.0%)]	Loss: 0.280747
#
# Train Epoch: 12 [40000/50000 (80.0%)]	Loss: 0.268793
#
# Test set: Average loss: 0.4418, Accuracy: 8597/10000 (86.0%)
#
#
# Train Epoch: 13 [0/50000 (0.0%)]	Loss: 0.249805
#
# Train Epoch: 13 [10000/50000 (20.0%)]	Loss: 0.261746
#
# Train Epoch: 13 [20000/50000 (40.0%)]	Loss: 0.320740
#
# Train Epoch: 13 [30000/50000 (60.0%)]	Loss: 0.418587
#
# Train Epoch: 13 [40000/50000 (80.0%)]	Loss: 0.348392
#
# Test set: Average loss: 0.4778, Accuracy: 8570/10000 (85.7%)
#
#
# Train Epoch: 14 [0/50000 (0.0%)]	Loss: 0.216936
#
# Train Epoch: 14 [10000/50000 (20.0%)]	Loss: 0.288283
#
# Train Epoch: 14 [20000/50000 (40.0%)]	Loss: 0.280808
#
# Train Epoch: 14 [30000/50000 (60.0%)]	Loss: 0.283419
#
# Train Epoch: 14 [40000/50000 (80.0%)]	Loss: 0.335754
#
# Test set: Average loss: 0.4353, Accuracy: 8690/10000 (86.9%)
#
#
# Train Epoch: 15 [0/50000 (0.0%)]	Loss: 0.370912
#
# Train Epoch: 15 [10000/50000 (20.0%)]	Loss: 0.102632
#
# Train Epoch: 15 [20000/50000 (40.0%)]	Loss: 0.227096
#
# Train Epoch: 15 [30000/50000 (60.0%)]	Loss: 0.304860
#
# Train Epoch: 15 [40000/50000 (80.0%)]	Loss: 0.197699
#
# Test set: Average loss: 0.4471, Accuracy: 8621/10000 (86.2%)
#
#
# Train Epoch: 16 [0/50000 (0.0%)]	Loss: 0.241417
#
# Train Epoch: 16 [10000/50000 (20.0%)]	Loss: 0.341684
#
# Train Epoch: 16 [20000/50000 (40.0%)]	Loss: 0.146381
#
# Train Epoch: 16 [30000/50000 (60.0%)]	Loss: 0.328547
#
# Train Epoch: 16 [40000/50000 (80.0%)]	Loss: 0.213489
#
# Test set: Average loss: 0.3955, Accuracy: 8756/10000 (87.6%)
#
#
# Train Epoch: 17 [0/50000 (0.0%)]	Loss: 0.207865
#
# Train Epoch: 17 [10000/50000 (20.0%)]	Loss: 0.163111
#
# Train Epoch: 17 [20000/50000 (40.0%)]	Loss: 0.300551
#
# Train Epoch: 17 [30000/50000 (60.0%)]	Loss: 0.216477
#
# Train Epoch: 17 [40000/50000 (80.0%)]	Loss: 0.405990
#
# Test set: Average loss: 0.4385, Accuracy: 8681/10000 (86.8%)
#
#
# Train Epoch: 18 [0/50000 (0.0%)]	Loss: 0.159450
#
# Train Epoch: 18 [10000/50000 (20.0%)]	Loss: 0.191779
#
# Train Epoch: 18 [20000/50000 (40.0%)]	Loss: 0.346158
#
# Train Epoch: 18 [30000/50000 (60.0%)]	Loss: 0.213424
#
# Train Epoch: 18 [40000/50000 (80.0%)]	Loss: 0.230945
#
# Test set: Average loss: 0.4001, Accuracy: 8778/10000 (87.8%)
#
#
# Train Epoch: 19 [0/50000 (0.0%)]	Loss: 0.136669
#
# Train Epoch: 19 [10000/50000 (20.0%)]	Loss: 0.264249
#
# Train Epoch: 19 [20000/50000 (40.0%)]	Loss: 0.268442
#
# Train Epoch: 19 [30000/50000 (60.0%)]	Loss: 0.258124
#
# Train Epoch: 19 [40000/50000 (80.0%)]	Loss: 0.177200
#
# Test set: Average loss: 0.4158, Accuracy: 8736/10000 (87.4%)
#
#
# Train Epoch: 20 [0/50000 (0.0%)]	Loss: 0.233548
#
# Train Epoch: 20 [10000/50000 (20.0%)]	Loss: 0.210881
#
# Train Epoch: 20 [20000/50000 (40.0%)]	Loss: 0.229785
#
# Train Epoch: 20 [30000/50000 (60.0%)]	Loss: 0.180838
#
# Train Epoch: 20 [40000/50000 (80.0%)]	Loss: 0.162248
#
# Test set: Average loss: 0.3478, Accuracy: 8983/10000 (89.8%)
#
#
# Train Epoch: 21 [0/50000 (0.0%)]	Loss: 0.237507
#
# Train Epoch: 21 [10000/50000 (20.0%)]	Loss: 0.127690
#
# Train Epoch: 21 [20000/50000 (40.0%)]	Loss: 0.147472
#
# Train Epoch: 21 [30000/50000 (60.0%)]	Loss: 0.131794
#
# Train Epoch: 21 [40000/50000 (80.0%)]	Loss: 0.133382
#
# Test set: Average loss: 0.3443, Accuracy: 9012/10000 (90.1%)
#
#
# Train Epoch: 22 [0/50000 (0.0%)]	Loss: 0.097722
#
# Train Epoch: 22 [10000/50000 (20.0%)]	Loss: 0.238249
#
# Train Epoch: 22 [20000/50000 (40.0%)]	Loss: 0.104421
#
# Train Epoch: 22 [30000/50000 (60.0%)]	Loss: 0.147875
#
# Train Epoch: 22 [40000/50000 (80.0%)]	Loss: 0.118342
#
# Test set: Average loss: 0.3565, Accuracy: 9027/10000 (90.3%)
#
#
# Train Epoch: 23 [0/50000 (0.0%)]	Loss: 0.177639
#
# Train Epoch: 23 [10000/50000 (20.0%)]	Loss: 0.110857
#
# Train Epoch: 23 [20000/50000 (40.0%)]	Loss: 0.081284
#
# Train Epoch: 23 [30000/50000 (60.0%)]	Loss: 0.168675
#
# Train Epoch: 23 [40000/50000 (80.0%)]	Loss: 0.102884
#
# Test set: Average loss: 0.3549, Accuracy: 9019/10000 (90.2%)
#
#
# Train Epoch: 24 [0/50000 (0.0%)]	Loss: 0.138857
#
# Train Epoch: 24 [10000/50000 (20.0%)]	Loss: 0.117911
#
# Train Epoch: 24 [20000/50000 (40.0%)]	Loss: 0.148718
#
# Train Epoch: 24 [30000/50000 (60.0%)]	Loss: 0.134707
#
# Train Epoch: 24 [40000/50000 (80.0%)]	Loss: 0.191749
#
# Test set: Average loss: 0.3550, Accuracy: 9013/10000 (90.1%)
#
#
# Train Epoch: 25 [0/50000 (0.0%)]	Loss: 0.089646
#
# Train Epoch: 25 [10000/50000 (20.0%)]	Loss: 0.120315
#
# Train Epoch: 25 [20000/50000 (40.0%)]	Loss: 0.147590
#
# Train Epoch: 25 [30000/50000 (60.0%)]	Loss: 0.140004
#
# Train Epoch: 25 [40000/50000 (80.0%)]	Loss: 0.151934
#
# Test set: Average loss: 0.3575, Accuracy: 9003/10000 (90.0%)
#
#
# Train Epoch: 26 [0/50000 (0.0%)]	Loss: 0.078963
#
# Train Epoch: 26 [10000/50000 (20.0%)]	Loss: 0.038826
#
# Train Epoch: 26 [20000/50000 (40.0%)]	Loss: 0.121092
#
# Train Epoch: 26 [30000/50000 (60.0%)]	Loss: 0.146029
#
# Train Epoch: 26 [40000/50000 (80.0%)]	Loss: 0.116040
#
# Test set: Average loss: 0.3716, Accuracy: 9002/10000 (90.0%)
#
#
# Train Epoch: 27 [0/50000 (0.0%)]	Loss: 0.104994
#
# Train Epoch: 27 [10000/50000 (20.0%)]	Loss: 0.199082
#
# Train Epoch: 27 [20000/50000 (40.0%)]	Loss: 0.080005
#
# Train Epoch: 27 [30000/50000 (60.0%)]	Loss: 0.150138
#
# Train Epoch: 27 [40000/50000 (80.0%)]	Loss: 0.049792
#
# Test set: Average loss: 0.3667, Accuracy: 9019/10000 (90.2%)
#
#
# Train Epoch: 28 [0/50000 (0.0%)]	Loss: 0.089170
#
# Train Epoch: 28 [10000/50000 (20.0%)]	Loss: 0.174209
#
# Train Epoch: 28 [20000/50000 (40.0%)]	Loss: 0.091259
#
# Train Epoch: 28 [30000/50000 (60.0%)]	Loss: 0.327288
#
# Train Epoch: 28 [40000/50000 (80.0%)]	Loss: 0.170838
#
# Test set: Average loss: 0.3775, Accuracy: 9031/10000 (90.3%)
#
#
# Train Epoch: 29 [0/50000 (0.0%)]	Loss: 0.029766
#
# Train Epoch: 29 [10000/50000 (20.0%)]	Loss: 0.130283
#
# Train Epoch: 29 [20000/50000 (40.0%)]	Loss: 0.139999
#
# Train Epoch: 29 [30000/50000 (60.0%)]	Loss: 0.047137
#
# Train Epoch: 29 [40000/50000 (80.0%)]	Loss: 0.169143
#
# Test set: Average loss: 0.3788, Accuracy: 9038/10000 (90.4%)
#
#
# Train Epoch: 30 [0/50000 (0.0%)]	Loss: 0.098303
#
# Train Epoch: 30 [10000/50000 (20.0%)]	Loss: 0.093789
#
# Train Epoch: 30 [20000/50000 (40.0%)]	Loss: 0.182506
#
# Train Epoch: 30 [30000/50000 (60.0%)]	Loss: 0.127037
#
# Train Epoch: 30 [40000/50000 (80.0%)]	Loss: 0.141992
#
# Test set: Average loss: 0.3718, Accuracy: 9042/10000 (90.4%)
#
#
# Train Epoch: 31 [0/50000 (0.0%)]	Loss: 0.176861
#
# Train Epoch: 31 [10000/50000 (20.0%)]	Loss: 0.108822
#
# Train Epoch: 31 [20000/50000 (40.0%)]	Loss: 0.068272
#
# Train Epoch: 31 [30000/50000 (60.0%)]	Loss: 0.087580
#
# Train Epoch: 31 [40000/50000 (80.0%)]	Loss: 0.077896
#
# Test set: Average loss: 0.3686, Accuracy: 9040/10000 (90.4%)
#
#
# Train Epoch: 32 [0/50000 (0.0%)]	Loss: 0.163850
#
# Train Epoch: 32 [10000/50000 (20.0%)]	Loss: 0.147098
#
# Train Epoch: 32 [20000/50000 (40.0%)]	Loss: 0.134589
#
# Train Epoch: 32 [30000/50000 (60.0%)]	Loss: 0.131739
#
# Train Epoch: 32 [40000/50000 (80.0%)]	Loss: 0.069135
#
# Test set: Average loss: 0.3671, Accuracy: 9040/10000 (90.4%)
#
#
# Train Epoch: 33 [0/50000 (0.0%)]	Loss: 0.056883
#
# Train Epoch: 33 [10000/50000 (20.0%)]	Loss: 0.120856
#
# Train Epoch: 33 [20000/50000 (40.0%)]	Loss: 0.120487
#
# Train Epoch: 33 [30000/50000 (60.0%)]	Loss: 0.123398
#
# Train Epoch: 33 [40000/50000 (80.0%)]	Loss: 0.106151
#
# Test set: Average loss: 0.3683, Accuracy: 9034/10000 (90.3%)
#
#
# Train Epoch: 34 [0/50000 (0.0%)]	Loss: 0.101918
#
# Train Epoch: 34 [10000/50000 (20.0%)]	Loss: 0.228540
#
# Train Epoch: 34 [20000/50000 (40.0%)]	Loss: 0.045888
#
# Train Epoch: 34 [30000/50000 (60.0%)]	Loss: 0.150174
#
# Train Epoch: 34 [40000/50000 (80.0%)]	Loss: 0.094265
#
# Test set: Average loss: 0.3710, Accuracy: 9038/10000 (90.4%)
#
#
# Train Epoch: 35 [0/50000 (0.0%)]	Loss: 0.063844
#
# Train Epoch: 35 [10000/50000 (20.0%)]	Loss: 0.051089
#
# Train Epoch: 35 [20000/50000 (40.0%)]	Loss: 0.167683
#
# Train Epoch: 35 [30000/50000 (60.0%)]	Loss: 0.079064
#
# Train Epoch: 35 [40000/50000 (80.0%)]	Loss: 0.082136
#
# Test set: Average loss: 0.3718, Accuracy: 9033/10000 (90.3%)
#
#
# Train Epoch: 36 [0/50000 (0.0%)]	Loss: 0.143946
#
# Train Epoch: 36 [10000/50000 (20.0%)]	Loss: 0.120747
#
# Train Epoch: 36 [20000/50000 (40.0%)]	Loss: 0.046360
#
# Train Epoch: 36 [30000/50000 (60.0%)]	Loss: 0.083062
#
# Train Epoch: 36 [40000/50000 (80.0%)]	Loss: 0.078035
#
# Test set: Average loss: 0.3710, Accuracy: 9035/10000 (90.3%)
#
#
# Train Epoch: 37 [0/50000 (0.0%)]	Loss: 0.130528
#
# Train Epoch: 37 [10000/50000 (20.0%)]	Loss: 0.180144
#
# Train Epoch: 37 [20000/50000 (40.0%)]	Loss: 0.082973
#
# Train Epoch: 37 [30000/50000 (60.0%)]	Loss: 0.027046
#
# Train Epoch: 37 [40000/50000 (80.0%)]	Loss: 0.147760
#
# Test set: Average loss: 0.3688, Accuracy: 9052/10000 (90.5%)
#
#
# Train Epoch: 38 [0/50000 (0.0%)]	Loss: 0.063216
#
# Train Epoch: 38 [10000/50000 (20.0%)]	Loss: 0.101510
#
# Train Epoch: 38 [20000/50000 (40.0%)]	Loss: 0.025366
#
# Train Epoch: 38 [30000/50000 (60.0%)]	Loss: 0.099166
#
# Train Epoch: 38 [40000/50000 (80.0%)]	Loss: 0.153701
#
# Test set: Average loss: 0.3669, Accuracy: 9051/10000 (90.5%)
#
#
# Train Epoch: 39 [0/50000 (0.0%)]	Loss: 0.064750
#
# Train Epoch: 39 [10000/50000 (20.0%)]	Loss: 0.120984
#
# Train Epoch: 39 [20000/50000 (40.0%)]	Loss: 0.144158
#
# Train Epoch: 39 [30000/50000 (60.0%)]	Loss: 0.202277
#
# Train Epoch: 39 [40000/50000 (80.0%)]	Loss: 0.062904
#
# Test set: Average loss: 0.3731, Accuracy: 9050/10000 (90.5%)
#
#
#  TRAIN PRUNED MODEL DONE!

# %% [markdown]
# ## 繪製Fine-tuning結果圖

# %%
#繪製Fine-tuning結果圖
import matplotlib.pyplot as plt

# 繪製Fine-tuning結果圖
plt.figure(figsize=(10, 6))
plt.plot(train_acc, label='Train Accuracy')
plt.plot(test_acc, label='Test Accuracy')
plt.title('Model Accuracy after Pruning and Fine-tuning')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## FLOPs & Parameters

# %%
# !pip install thop
# !pip install torchsummary
# Out:
# Requirement already satisfied: thop in /usr/local/lib/python3.12/dist-packages (0.1.1.post2209072238)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from thop) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->thop) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->thop) (3.0.3)
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.12/dist-packages (1.5.1)

# %%
from thop import profile
from torchsummary import summary

##### 使用 thop 計算 FLOPs 和參數數量 #####
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
model = model.to(device)

dummy_input = torch.randn(1, 3, 32, 32).to(device)
flops, params = profile(model, inputs=(dummy_input, ))

print(f"FLOPs: {flops}")
print(f"Params: {params}")
summary(model, input_size=(3, 32, 32))
# Out:
# Device: cuda
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# FLOPs: 103002692.0
# Params: 3315698.0
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5           [-1, 64, 16, 16]           4,096
#        BatchNorm2d-6           [-1, 64, 16, 16]             128
#               ReLU-7           [-1, 64, 16, 16]               0
#             Conv2d-8           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-9           [-1, 64, 16, 16]             128
#              ReLU-10           [-1, 64, 16, 16]               0
#            Conv2d-11          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-12          [-1, 256, 16, 16]             512
#            Conv2d-13          [-1, 256, 16, 16]          16,384
#              ReLU-14          [-1, 256, 16, 16]               0
#        Bottleneck-15          [-1, 256, 16, 16]               0
#            Conv2d-16           [-1, 64, 16, 16]          16,384
#       BatchNorm2d-17           [-1, 64, 16, 16]             128
#              ReLU-18           [-1, 64, 16, 16]               0
#            Conv2d-19           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-20           [-1, 64, 16, 16]             128
#              ReLU-21           [-1, 64, 16, 16]               0
#            Conv2d-22          [-1, 256, 16, 16]          16,384
#       BatchNorm2d-23          [-1, 256, 16, 16]             512
#              ReLU-24          [-1, 256, 16, 16]               0
#        Bottleneck-25          [-1, 256, 16, 16]               0
#            Conv2d-26           [-1, 63, 16, 16]          16,128
#       BatchNorm2d-27           [-1, 63, 16, 16]             126
#              ReLU-28           [-1, 63, 16, 16]               0
#            Conv2d-29           [-1, 62, 16, 16]          35,154
#       BatchNorm2d-30           [-1, 62, 16, 16]             124
#              ReLU-31           [-1, 62, 16, 16]               0
#            Conv2d-32          [-1, 256, 16, 16]          15,872
#       BatchNorm2d-33          [-1, 256, 16, 16]             512
#              ReLU-34          [-1, 256, 16, 16]               0
#        Bottleneck-35          [-1, 256, 16, 16]               0
#            Conv2d-36           [-1, 69, 16, 16]          17,664
#       BatchNorm2d-37           [-1, 69, 16, 16]             138
#              ReLU-38           [-1, 69, 16, 16]               0
#            Conv2d-39             [-1, 74, 8, 8]          45,954
#       BatchNorm2d-40             [-1, 74, 8, 8]             148
#              ReLU-41             [-1, 74, 8, 8]               0
#            Conv2d-42            [-1, 512, 8, 8]          37,888
#       BatchNorm2d-43            [-1, 512, 8, 8]           1,024
#            Conv2d-44            [-1, 512, 8, 8]         131,072
#              ReLU-45            [-1, 512, 8, 8]               0
#        Bottleneck-46            [-1, 512, 8, 8]               0
#            Conv2d-47             [-1, 31, 8, 8]          15,872
#       BatchNorm2d-48             [-1, 31, 8, 8]              62
#              ReLU-49             [-1, 31, 8, 8]               0
#            Conv2d-50             [-1, 58, 8, 8]          16,182
#       BatchNorm2d-51             [-1, 58, 8, 8]             116
#              ReLU-52             [-1, 58, 8, 8]               0
#            Conv2d-53            [-1, 512, 8, 8]          29,696
#       BatchNorm2d-54            [-1, 512, 8, 8]           1,024
#              ReLU-55            [-1, 512, 8, 8]               0
#        Bottleneck-56            [-1, 512, 8, 8]               0
#            Conv2d-57             [-1, 42, 8, 8]          21,504
#       BatchNorm2d-58             [-1, 42, 8, 8]              84
#              ReLU-59             [-1, 42, 8, 8]               0
#            Conv2d-60             [-1, 50, 8, 8]          18,900
#       BatchNorm2d-61             [-1, 50, 8, 8]             100
#              ReLU-62             [-1, 50, 8, 8]               0
#            Conv2d-63            [-1, 512, 8, 8]          25,600
#       BatchNorm2d-64            [-1, 512, 8, 8]           1,024
#              ReLU-65            [-1, 512, 8, 8]               0
#        Bottleneck-66            [-1, 512, 8, 8]               0
#            Conv2d-67             [-1, 12, 8, 8]           6,144
#       BatchNorm2d-68             [-1, 12, 8, 8]              24
#              ReLU-69             [-1, 12, 8, 8]               0
#            Conv2d-70             [-1, 16, 8, 8]           1,728
#       BatchNorm2d-71             [-1, 16, 8, 8]              32
#              ReLU-72             [-1, 16, 8, 8]               0
#            Conv2d-73            [-1, 512, 8, 8]           8,192
#       BatchNorm2d-74            [-1, 512, 8, 8]           1,024
#              ReLU-75            [-1, 512, 8, 8]               0
#        Bottleneck-76            [-1, 512, 8, 8]               0
#            Conv2d-77              [-1, 1, 8, 8]             512
#       BatchNorm2d-78              [-1, 1, 8, 8]               2
#              ReLU-79              [-1, 1, 8, 8]               0
#            Conv2d-80              [-1, 3, 4, 4]              27
#       BatchNorm2d-81              [-1, 3, 4, 4]               6
#              ReLU-82              [-1, 3, 4, 4]               0
#            Conv2d-83           [-1, 1024, 4, 4]           3,072
#       BatchNorm2d-84           [-1, 1024, 4, 4]           2,048
#            Conv2d-85           [-1, 1024, 4, 4]         524,288
#              ReLU-86           [-1, 1024, 4, 4]               0
#        Bottleneck-87           [-1, 1024, 4, 4]               0
#            Conv2d-88              [-1, 1, 4, 4]           1,024
#       BatchNorm2d-89              [-1, 1, 4, 4]               2
#              ReLU-90              [-1, 1, 4, 4]               0
#            Conv2d-91              [-1, 2, 4, 4]              18
#       BatchNorm2d-92              [-1, 2, 4, 4]               4
#              ReLU-93              [-1, 2, 4, 4]               0
#            Conv2d-94           [-1, 1024, 4, 4]           2,048
#       BatchNorm2d-95           [-1, 1024, 4, 4]           2,048
#              ReLU-96           [-1, 1024, 4, 4]               0
#        Bottleneck-97           [-1, 1024, 4, 4]               0
#            Conv2d-98              [-1, 1, 4, 4]           1,024
#       BatchNorm2d-99              [-1, 1, 4, 4]               2
#             ReLU-100              [-1, 1, 4, 4]               0
#           Conv2d-101              [-1, 1, 4, 4]               9
#      BatchNorm2d-102              [-1, 1, 4, 4]               2
#             ReLU-103              [-1, 1, 4, 4]               0
#           Conv2d-104           [-1, 1024, 4, 4]           1,024
#      BatchNorm2d-105           [-1, 1024, 4, 4]           2,048
#             ReLU-106           [-1, 1024, 4, 4]               0
#       Bottleneck-107           [-1, 1024, 4, 4]               0
#           Conv2d-108              [-1, 1, 4, 4]           1,024
#      BatchNorm2d-109              [-1, 1, 4, 4]               2
#             ReLU-110              [-1, 1, 4, 4]               0
#           Conv2d-111              [-1, 1, 4, 4]               9
#      BatchNorm2d-112              [-1, 1, 4, 4]               2
#             ReLU-113              [-1, 1, 4, 4]               0
#           Conv2d-114           [-1, 1024, 4, 4]           1,024
#      BatchNorm2d-115           [-1, 1024, 4, 4]           2,048
#             ReLU-116           [-1, 1024, 4, 4]               0
#       Bottleneck-117           [-1, 1024, 4, 4]               0
#           Conv2d-118              [-1, 1, 4, 4]           1,024
#      BatchNorm2d-119              [-1, 1, 4, 4]               2
#             ReLU-120              [-1, 1, 4, 4]               0
#           Conv2d-121              [-1, 1, 4, 4]               9
#      BatchNorm2d-122              [-1, 1, 4, 4]               2
#             ReLU-123              [-1, 1, 4, 4]               0
#           Conv2d-124           [-1, 1024, 4, 4]           1,024
#      BatchNorm2d-125           [-1, 1024, 4, 4]           2,048
#             ReLU-126           [-1, 1024, 4, 4]               0
#       Bottleneck-127           [-1, 1024, 4, 4]               0
#           Conv2d-128              [-1, 1, 4, 4]           1,024
#      BatchNorm2d-129              [-1, 1, 4, 4]               2
#             ReLU-130              [-1, 1, 4, 4]               0
#           Conv2d-131              [-1, 1, 4, 4]               9
#      BatchNorm2d-132              [-1, 1, 4, 4]               2
#             ReLU-133              [-1, 1, 4, 4]               0
#           Conv2d-134           [-1, 1024, 4, 4]           1,024
#      BatchNorm2d-135           [-1, 1024, 4, 4]           2,048
#             ReLU-136           [-1, 1024, 4, 4]               0
#       Bottleneck-137           [-1, 1024, 4, 4]               0
#           Conv2d-138              [-1, 3, 4, 4]           3,072
#      BatchNorm2d-139              [-1, 3, 4, 4]               6
#             ReLU-140              [-1, 3, 4, 4]               0
#           Conv2d-141              [-1, 1, 2, 2]              27
#      BatchNorm2d-142              [-1, 1, 2, 2]               2
#             ReLU-143              [-1, 1, 2, 2]               0
#           Conv2d-144           [-1, 2048, 2, 2]           2,048
#      BatchNorm2d-145           [-1, 2048, 2, 2]           4,096
#           Conv2d-146           [-1, 2048, 2, 2]       2,097,152
#             ReLU-147           [-1, 2048, 2, 2]               0
#       Bottleneck-148           [-1, 2048, 2, 2]               0
#           Conv2d-149              [-1, 5, 2, 2]          10,240
#      BatchNorm2d-150              [-1, 5, 2, 2]              10
#             ReLU-151              [-1, 5, 2, 2]               0
#           Conv2d-152              [-1, 9, 2, 2]             405
#      BatchNorm2d-153              [-1, 9, 2, 2]              18
#             ReLU-154              [-1, 9, 2, 2]               0
#           Conv2d-155           [-1, 2048, 2, 2]          18,432
#      BatchNorm2d-156           [-1, 2048, 2, 2]           4,096
#             ReLU-157           [-1, 2048, 2, 2]               0
#       Bottleneck-158           [-1, 2048, 2, 2]               0
#           Conv2d-159              [-1, 1, 2, 2]           2,048
#      BatchNorm2d-160              [-1, 1, 2, 2]               2
#             ReLU-161              [-1, 1, 2, 2]               0
#           Conv2d-162              [-1, 1, 2, 2]               9
#      BatchNorm2d-163              [-1, 1, 2, 2]               2
#             ReLU-164              [-1, 1, 2, 2]               0
#           Conv2d-165           [-1, 2048, 2, 2]           2,048
#      BatchNorm2d-166           [-1, 2048, 2, 2]           4,096
#             ReLU-167           [-1, 2048, 2, 2]               0
#       Bottleneck-168           [-1, 2048, 2, 2]               0
# AdaptiveAvgPool2d-169           [-1, 2048, 1, 1]               0
#           Linear-170                   [-1, 10]          20,490
# ================================================================
# Total params: 3,315,698
# Trainable params: 3,315,698
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 19.39
# Params size (MB): 12.65
# Estimated Total Size (MB): 32.05
# ----------------------------------------------------------------
